# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

import stan
import arviz as az

import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# ## Introduction
#
# In this notebook, we will estimate the parameters of the simple diffusion model from a simulated response times (RTs) data set using Stan's implementation of Hamiltonian Monte Carlo (HMC). But, wait! Since we are simulating the data (i.e., solving the forward problem), don't we already know the parameters with absolute certainty? Indeed, in this case we do, and this little exercise will introduce a crucial principle of all computational modeling: **Parametric models are nothing but assumptions about the unknown data-generating process**, so, in a way, the inverse problem (i.e., going from data to parameters) presupposes the forward problem.
#
# Thus, even when we are estimating the parameters from an actually observed data set, we are assuming that the parametric model is the accurate description of the system that generated the data. In other words, we hope that our model is *well-specified*. Simulation studies enable science *in silico*, that is, before collecting any data, we can already play oracles and test what we can learn from the data by successively solving the forward and the inverse problem.

# %% [markdown]
# ## Diffusion Model Simulator

# %%
def simulate_diffusion(v, a, beta, tau, dt=1e-3, scale=1.0, max_time=10., rng=None):
    """
    Simulates one realization of the diffusion process given
    a set of parameters and a step size `dt`.

    Parameters:
    -----------
    v        : float
        The drift rate (rate of information uptake)
    a        : float
        The boundary separation (decision threshold).
    beta     : float in [0, 1]
        Relative starting point (prior option preferences)
    tau      : float
        Non-decision time (additive constant)
    dt       : float, optional (default: 1e-3 = 0.001)
        The step size for the Euler algorithm.
    scale    : float, optional (default: 1.0)
        The scale (sqrt(var)) of the Wiener process. Not considered
        a parameter and typically fixed to either 1.0 or 0.1.
    max_time : float, optional (default: .10)
        The maximum number of seconds before forced termination.
    rng      : np.random.Generator or None, optional (default: None)
        A random number generator with locally set seed or None
        If None provided, a new generator will be spawned within the function.
        
    Returns:
    --------
    (x, c) - a tuple of response time (y - float) and a 
        binary decision (c - int) 
    """

    # Inits (process starts at relative starting point)
    y = beta * a
    num_steps = tau
    const = scale*np.sqrt(dt)
    if rng is None:
        rng = np.random.default_rng()

    # Loop through process and check boundary conditions
    while (y <= a and y >= 0) and num_steps <= max_time:

        # Perform diffusion equation
        z = rng.normal()
        y += v*dt + const*z

        # Increment step counter
        num_steps += dt

    if y >= a:
        c = 1.
    else:
        c = 0.
    return (round(num_steps, 4), c)

# %% [markdown]
# ## Helper Functions

# %%
def simulate_diffusion_n(num_sims, v, a, beta, tau, dt=1e-3, scale=1.0, max_time=10., rng=None):
    """Add a nice docstring."""

    # Inits
    data = np.zeros((num_sims, 2))
    if rng is None:
        rng = np.random.default_rng()
    
    # Create data set
    for n in range(num_sims):
        data[n, :] = simulate_diffusion(v, a, beta, tau, dt, scale, max_time, rng)
    return data


def visualize_data(data, figsize=(10, 5)):
    """Helper function to visualize a simple response time data set."""

    f, axarr = plt.subplots(1, 2, figsize=figsize)
    
    # Histogram of response times
    sns.histplot(
        data[:, 0][data[:, 1] == 1], ax=axarr[0], color='#AA0000', alpha=0.8, lw=2, label=f'Response 1')
    sns.histplot(
        data[:, 0][data[:, 1] == 0], ax=axarr[0], color='#0000AA', alpha=0.8, lw=2, label=f'Response 0')

    # Barplot of categorical responses
    response, frequency = np.unique(data[:, 1], return_counts=True)
    sns.barplot(x=response.astype(np.int32), y=frequency, ax=axarr[1], alpha=0.8, color='#00AA00')

    # Labels and embelishments
    axarr[0].set_xlabel('Response time (s)', fontsize=16)
    axarr[0].legend(fontsize=16)
    axarr[0].set_ylabel('Count', fontsize=16)
    axarr[1].set_xlabel('Response', fontsize=16)
    axarr[1].set_ylabel('Frequency', fontsize=16)
    for ax in axarr:
        sns.despine(ax=ax)
        ax.grid(alpha=0.1, color='black')

    f.suptitle('Data Summary', fontsize=18)

    f.tight_layout()

# %%
# Ensure reproducibility
RNG = np.random.default_rng(2024)

# Set ground-truth parameters
parameters = {
    'v': 1.6,
    'a': 0.8,
    'beta': 0.6,
    'tau': 0.4
}

# Set additional simulation settings
control = {
    'num_sims': 120,
    'rng': RNG,
    'dt': 1e-3
}

# Create data with above configuration
data = simulate_diffusion_n(**{**control, **parameters})

# %%
visualize_data(data)

# %% [markdown]
# ## Bayesian Parameter Estimation
#
# Now, we will write a Stan program to sample from the posterior of the diffusion model parameters given the observed data.

# %% [markdown]
# ### Prior Distributions

# %%
### Visualizing our priors the lazy way
f, axarr = plt.subplots(1, 4, figsize=(12, 3))
param_names = [r'Drift rate ($v$)', r'Boundary separation ($a$)', r'Bias ($\beta$)', r'Non-decision time ($\tau$)']
sns.histplot(np.random.gamma(3, 1, size=100000), color='maroon', ax=axarr[0])
sns.histplot(np.random.gamma(3, 1, size=100000), color='maroon', ax=axarr[1])
sns.histplot(np.random.beta(2, 2, size=100000), color='maroon', ax=axarr[2])
sns.histplot(np.random.gamma(2, 1, size=100000), color='maroon', ax=axarr[3])

for ax, p in zip(axarr, param_names):
    ax.set_title(p, fontsize=14)
    ax.set_xlabel('Parameter value', fontsize=12)
    ax.set_yticks([])
    ax.set_ylabel('')
    sns.despine(ax=ax)

f.tight_layout()

# %% [markdown]
# ### Stan Program

# %%
program_code = """

data {
    int<lower=1> N;
    vector[N] y;
    vector[N] c;
}

parameters {
    real<lower=0> v;
    real<lower=0> a;
    real<lower=0> tau;
    real<lower=0, upper=1> beta;
}

model {
    // Priors
    v ~ gamma(3, 1);
    a ~ gamma(3, 1);
    beta ~ beta(2, 2);
    tau ~ gamma(2, 1);

    // Likelihood (Wiener Model)
    for (n in 1:N) {
        if (c[n] == 1) {
            y[n] ~ wiener(a, tau, beta, v);
        }
        else {
            y[n] ~ wiener(a, tau, 1-beta, -v);
        }
    }
}
"""

# %% [markdown]
# ### Compilation and Sampling

# %%
# Prepare data in Stan friendly format
data_dict = {
    'y': data[:, 0], 
    'c': data[:, 1].astype(int),
    'N': data.shape[0]
}

# Compile model

model = stan.build(program_code, data = data_dict)
# Out:
# Building...
# Building: 28.7s, done.

# %%
# Posterior inference using MCMC
fit = model.sample(num_chains=4, num_warmup=1000, num_samples=2000)
# Out:
# Sampling:   0%
# Sampling:   0% (1/12000)
# Sampling:   0% (2/12000)
# Sampling:   0% (3/12000)
# Sampling:   0% (4/12000)
# Sampling:   1% (103/12000)
# Sampling:   2% (202/12000)
# Sampling:   3% (301/12000)
# Sampling:   3% (401/12000)
# Sampling:   4% (500/12000)
# Sampling:   6% (700/12000)
# Sampling:   8% (900/12000)
# Sampling:   8% (1000/12000)
# Sampling:  10% (1200/12000)
# Sampling:  12% (1400/12000)
# Sampling:  13% (1600/12000)
# Sampling:  15% (1800/12000)
# Sampling:  17% (2000/12000)
# Sampling:  18% (2200/12000)
# Sampling:  20% (2400/12000)
# Sampling:  22% (2600/12000)
# Sampling:  23% (2800/12000)
# Sampling:  25% (3000/12000)
# Sampling:  44% (5300/12000)
# Sampling:  63% (7600/12000)
# Sampling:  82% (9900/12000)
# Sampling: 100% (12000/12000)
# Sampling: 100% (12000/12000), done.
# Messages received during sampling:
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 0.892238 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 0.80889 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   Gradient evaluation took 0.001096 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 10.96 seconds.
#   Adjust your expectations accordingly!
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 2.54032e+102 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 1.36316e+102 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 1.51395e+25 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 1.06322e+06 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 16.2345 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 1.01396 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.459, but must be greater than nondecision time = 0.480076 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.412535 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: gamma_lpdf: Random variable is inf, but must be positive finite! (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 19, column 4 to column 20)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 5.43318e+54 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 0.897702 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.423, but must be greater than nondecision time = 0.423924 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.416, but must be greater than nondecision time = 0.41987 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.452, but must be greater than nondecision time = 0.452011 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.414035 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 0.533201 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 0.594415 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.459, but must be greater than nondecision time = 0.469989 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 2.72119 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 1.70325 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 2.59847 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 0.648165 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 3.12577 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   Gradient evaluation took 0.001426 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 14.26 seconds.
#   Adjust your expectations accordingly!
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: gamma_lpdf: Random variable is inf, but must be positive finite! (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 19, column 4 to column 20)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: gamma_lpdf: Random variable is inf, but must be positive finite! (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 19, column 4 to column 20)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 8.45773e+69 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 1.20894e+17 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 5416.53 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 3.08204 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.427, but must be greater than nondecision time = 0.43041 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: gamma_lpdf: Random variable is 0, but must be positive finite! (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 18, column 4 to column 20)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: gamma_lpdf: Random variable is inf, but must be positive finite! (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 19, column 4 to column 20)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 5.70714e+07 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 0.543443 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.414105 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.412765 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.416, but must be greater than nondecision time = 0.420928 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.427, but must be greater than nondecision time = 0.434548 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.414017 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.414831 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.416, but must be greater than nondecision time = 0.421182 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.415018 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.416, but must be greater than nondecision time = 0.42139 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.414049 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.416, but must be greater than nondecision time = 0.417519 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 0.552568 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.459, but must be greater than nondecision time = 0.460791 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 29, column 12 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.414026 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.416, but must be greater than nondecision time = 0.421359 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.423, but must be greater than nondecision time = 0.423019 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 2.48482 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 1.71464 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 1.99086 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 1.36151 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 0.509175 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 1.78858 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.459, but must be greater than nondecision time = 0.47629 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 29, column 12 to column 46)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 3.93027 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 0.574118 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 3.26655 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 1.04471 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 1.97407 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 0.815056 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 4.42292 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   Gradient evaluation took 0.001886 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 18.86 seconds.
#   Adjust your expectations accordingly!
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 1.93083e+89 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 1.2167e+89 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 5.54234e+21 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 118755 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 6.3529 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 0.489186 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: gamma_lpdf: Random variable is inf, but must be positive finite! (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 18, column 4 to column 20)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 1.21251e+240 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 69.2929 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.412944 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.416, but must be greater than nondecision time = 0.420119 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.415559 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.41242 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 0.844029 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.412033 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.416, but must be greater than nondecision time = 0.416196 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.412328 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.412992 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.413052 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.427, but must be greater than nondecision time = 0.449866 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 0.81832 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 3.4411 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 1.12989 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 6.86092 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   Gradient evaluation took 0.001355 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 13.55 seconds.
#   Adjust your expectations accordingly!
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 4.78509e+298 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 9.43293e+298 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 1.33188e+74 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 2.09922e+18 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 18994.8 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 5.53249 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 0.736874 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.423, but must be greater than nondecision time = 0.42349 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.427, but must be greater than nondecision time = 0.427611 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: gamma_lpdf: Random variable is inf, but must be positive finite! (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 19, column 4 to column 20)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 9.6896e+158 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 5.25892 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.414642 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.416, but must be greater than nondecision time = 0.418951 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.423, but must be greater than nondecision time = 0.426578 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.427, but must be greater than nondecision time = 0.435105 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.412, but must be greater than nondecision time = 0.413806 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.423, but must be greater than nondecision time = 0.42606 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 0.514886 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.427, but must be greater than nondecision time = 0.437516 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.427, but must be greater than nondecision time = 0.43439 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 0.696753 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.427, but must be greater than nondecision time = 0.42707 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.416, but must be greater than nondecision time = 0.418072 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: wiener_lpdf: Random variable  = 0.486, but must be greater than nondecision time = 0.491718 (in '/tmp/httpstan_prfd094t/model_tkzxz3xf.stan', line 26, column 12 to column 43)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.

# %%
# Extract samples
df = fit.to_frame()

# %%
# Posterior summary statistics
az.summary(fit)
# Out:
#        mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# v     2.030  0.312   1.414    2.592      0.005    0.004    3708.0    3515.0
# a     0.902  0.050   0.811    0.998      0.001    0.001    4084.0    4703.0
# tau   0.391  0.006   0.380    0.401      0.000    0.000    3462.0    3855.0
# beta  0.554  0.040   0.478    0.624      0.001    0.000    3528.0    4169.0
#
#       r_hat
# v       1.0
# a       1.0
# tau     1.0
# beta    1.0

# %%
# Traceplots 
f = az.plot_trace(fit, compact=False, legend=True)
plt.tight_layout()

# %% [markdown]
# ## Real-Data Application

# %%
# Reading in example response times (RT) data
df = pd.read_csv('sample_response_times.csv', delimiter=';')

# %%
df
# Out:
#          #TIME  TRIAL  RESPONSE      RT  PRIME  TARGET         TYPE  \
# 0      82.2292      1         0  0.4851      0       1  incongruent
# 1      85.9700      2         0  0.5515      1       0  incongruent
# 2      89.2500      3         1  0.6348      1       0    congruent
# 3      92.6600      4         0  0.7683      0       0    congruent
# 4      96.5800      5         1  0.5181      1       1  incongruent
# ..         ...    ...       ...     ...    ...     ...          ...
# 235  1106.0000    236         0  0.5176      0       0    congruent
# 236  1110.0000    237         0  0.4681      0       0    congruent
# 237  1115.0000    238         0  0.5842      0       0    congruent
# 238  1118.0000    239         0  0.4674      1       0    congruent
# 239  1121.0000    240         0  0.7009      1       0  incongruent
#
#         RESULT  QUESTION
# 0    incorrect         0
# 1      correct         0
# 2    incorrect         0
# 3      correct         0
# 4      correct         0
# ..         ...       ...
# 235    correct         0
# 236    correct         1
# 237    correct         0
# 238    correct         0
# 239    correct         1
#
# [240 rows x 9 columns]

# %%
### Your code here
